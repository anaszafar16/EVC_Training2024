# %% [markdown]
# Use EasyOCR model from Pytorch to recognize characters in an image.
#
# You have to display the bounding box and the recognized characters on the image.
#
# Choose any images you want.
#
# OCR with EasyOCR: https://medium.com/@ilaslanduzgun/optical-character-recognition-ocr-with-easyocr-pytorch-27232272ab38
#
# OCR with Pytorch: https://www.youtube.com/watch?v=ZVKaWPW9oQY

# %%
# !pip install easyocr opencv-python matplotlib

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# %%
# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])

# Read the image
image_path = '/content/img.jpg'
image = cv2.imread(image_path)

# Perform OCR on the image
result = reader.readtext(image)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Define colors for the bounding boxes and text
bbox_color = (0, 255, 0)  # Green for bounding boxes
text_color = (255, 0, 0)  # Blue for text

# Iterate over the detected text boxes
for (bbox, text, prob) in result:
    # Extract the bounding box coordinates
    (top_left, top_right, bottom_right, bottom_left) = bbox
    top_left = tuple(map(int, top_left))
    bottom_right = tuple(map(int, bottom_right))

    # Draw the bounding box
    cv2.rectangle(image, top_left, bottom_right, bbox_color, 2)

    # Put the text label above the bounding box
    cv2.putText(image, text, (top_left[0], top_left[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, text_color, 2)

# %%
# Convert the image to RGB (OpenCV uses BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
